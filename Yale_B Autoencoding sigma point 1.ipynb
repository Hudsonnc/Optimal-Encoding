# %%
import re
import numpy as np
import math
import tensorflow as tf

from matplotlib import pyplot as plt
# %matplotlib inline
import sklearn.datasets
from sklearn import preprocessing, model_selection

# %% [markdown]
# # Data loading

# %%
# I use the code snippet from https://stackoverflow.com/questions/7368739/numpy-and-16-bit-pgm/7369986
# It read PGM image buffer string and return a numpy array
def read_pgm2(buffer, byteorder='>'):
    """Return image data from a raw PGM file as numpy array.
    Format specification: http://netpbm.sourceforge.net/doc/pgm.html
    """
    #with open(filename, 'rb') as f:
    #    buffer = f.read()
    try:
        header, width, height, maxval = re.search(
            b"(^P5\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n])*"
            b"(\d+)\s(?:\s*#.*[\r\n]\s)*)", buffer).groups()
    except AttributeError:
        raise ValueError("Not a raw PGM file: '%s'" % filename)
    #print 'width',width, 'height', height
    
    return np.frombuffer(buffer,
                            dtype='u1' if int(maxval) < 256 else byteorder+'u2',
                            count=int(width)*int(height),
                            offset=15#len(header)
                            ).reshape((int(height), int(width)))

# %%
dataset0 = sklearn.datasets.load_files('data/CroppedYale', shuffle=True)

# %%
# Here is some sanity checks of the parsed dataset
idx0 = 10 #len(dataset0.filenames)-1
print(dataset0.filenames[idx0])
print(dataset0.target[idx0])
print(dataset0.target_names[dataset0.target[idx0]])
print(len(dataset0.filenames))
image0 = read_pgm2(dataset0.data[idx0])
plt.imshow(image0, plt.cm.gray)
# Out:
# data/CroppedYale/yaleB36/yaleB36_P00A+070E-35.pgm
# 34
# yaleB36
# 2432

# %%
# This cell includes the splittign of training and test set.
X = np.stack(map(read_pgm2, dataset0.data))
# X = X[:size0]

shapeX = X.shape
X = X.reshape((shapeX[0],shapeX[1]*shapeX[2]))
X = preprocessing.scale(X.astype(float),axis=1) # Mean removal and variance scaling

y = dataset0.target
enc = preprocessing.OneHotEncoder()
y = enc.fit_transform(y.reshape(-1, 1)).toarray()
# y = y.reshape(-1)
# y = y[:size0]

X_train, X_test, y_train, y_test = model_selection.train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# # Optimal Encoding

# %%
from networks import MLP
from OptimalEncoding import OptimalEncoding
# Out:
# WARNING:tensorflow:From /home/hudson/anaconda3/envs/tensorflow/lib/python3.6/site-packages/tensorflow/contrib/learn/python/learn/datasets/base.py:198: retry (from tensorflow.contrib.learn.python.learn.datasets.base) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use the retry module or similar alternatives.

# %% [markdown]
# ## Autoencoding

# %%
n_in = X.shape[-1]
k = 10
n_out = X.shape[-1]

widths = [300, 300]
depth = len(widths)

# %%
encoder = MLP(n_in, k, depth, widths)
decoder = MLP(k, n_out+1, depth, widths)

# %%
oe = OptimalEncoding(encoder, decoder, k)

# %%
oe.train(X_train, y=None, min_entropy=True, epochs=1000, batch_size=64, lr=1e-3, sigma = .1, task = 'autoencoder')
# Out:
# 100%|██████████| 1000/1000 [07:03<00:00,  2.36it/s]
# Final task loss: 14199.525273

# %%
zhat = oe.encode(X_test)

# %%
plt.scatter(zhat[:,3], zhat[:,8])

# %%
X_test.shape
# Out:
# (803, 32256)

# %%
oe.decode(zhat).shape
# Out:
# (803, 32256)

# %%
xhat = oe.decode(zhat)

fig, ax = plt.subplots(figsize = (20,10), nrows=2, ncols=5)
for i in range(len(ax)):
    row = ax[i]
    for j in range(len(row)):
        subplt = row[j]
        if i == 0:
            subplt.set_title("$X_%d$" %(j))
            subplt.imshow(X_test[j].reshape((shapeX[1],shapeX[2])), plt.cm.gray)
        if i == 1:
            subplt.set_title("$\hat{X}_%d$" %(j))
            subplt.imshow(xhat[j].reshape((shapeX[1],shapeX[2])), plt.cm.gray)
        
        subplt.axis('off')
        
fig.subplots_adjust(wspace=None, hspace=None)
plt.show()

# %% [markdown]
# # SubOptimal Encoding

# %% [markdown]
# ## Autoencoding

# %%
n_in = X.shape[-1]
k = 10
n_out = X.shape[-1]

widths = [300, 300]
depth = len(widths)

# %%
encoder = MLP(n_in, k, depth, widths)
decoder = MLP(k, n_out+1, depth, widths)

# %%
oe = OptimalEncoding(encoder, decoder, k)

# %%
oe.train(X_train, y=None, min_entropy=False, epochs=1000, batch_size=64, lr=1e-3, sigma = .1, task = 'autoencoder')
# Out:
# 100%|██████████| 1000/1000 [07:02<00:00,  2.37it/s]
# Final task loss: 12207.935234

# %%
zhat = oe.encode(X_test)

# %%
plt.scatter(zhat[:,3], zhat[:,8])

# %%
X_test.shape
# Out:
# (803, 32256)

# %%
oe.decode(zhat).shape
# Out:
# (803, 32256)

# %%
xhat = oe.decode(zhat)

fig, ax = plt.subplots(figsize = (20,10), nrows=2, ncols=5)
for i in range(len(ax)):
    row = ax[i]
    for j in range(len(row)):
        subplt = row[j]
        if i == 0:
            subplt.set_title("$X_%d$" %(j))
            subplt.imshow(X_test[j].reshape((shapeX[1],shapeX[2])), plt.cm.gray)
        if i == 1:
            subplt.set_title("$\hat{X}_%d$" %(j))
            subplt.imshow(xhat[j].reshape((shapeX[1],shapeX[2])), plt.cm.gray)
        
        subplt.axis('off')
        
fig.subplots_adjust(wspace=None, hspace=None)
plt.show()
